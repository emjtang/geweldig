# %%
import pickle
from PIL import Image
import matplotlib.pyplot as plt
import argparse
# %matplotlib inline

import sys
print sys.path
# import torch
# import torch.nn as nn
# from torch.autograd import Variable
# from torch.utils.data import DataLoader

#import torchvision
#import torchvision.transforms as T
#from torchvision.datasets import ImageFolder
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD = [0.229, 0.224, 0.225]

saliency = pickle.load(open('saliency.pkl', 'rb'))
# X = pickle.load(open('X.pkl', 'rb'))
N = 1
# for i in range(N):
plt.imshow(saliency, cmap=plt.cm.hot)

#     plt.subplot(2, N, i + 1)
# #     plt.imshow(X[i])
# #     plt.imshow(X)
#     plt.axis('off')
#     #plt.title(class_names[y[i]])
# #     plt.subplot(2, N, N + i + 1)
#     plt.imshow(saliency[i], cmap=plt.cm.hot)
#     plt.axis('off')
#     plt.gcf().set_size_inches(12, 5)
plt.show()
# Out:
# ['', '/home/tarabalakrishnan/geweldig/geweldigGC/lib/python2.7/site-packages', '', '/usr/lib/python2.7', '/usr/lib/python2.7/plat-x86_64-linux-gnu', '/usr/lib/python2.7/lib-tk', '/usr/lib/python2.7/lib-old', '/usr/lib/python2.7/lib-dynload', '/home/emjtang/.local/lib/python2.7/site-packages', '/usr/local/lib/python2.7/dist-packages', '/usr/lib/python2.7/dist-packages', '/usr/local/lib/python2.7/dist-packages/IPython/extensions', '/home/emjtang/.ipython', '/home/tarabalakrishnan/geweldig/geweldigGC/lib/python2.7/site-packages']
